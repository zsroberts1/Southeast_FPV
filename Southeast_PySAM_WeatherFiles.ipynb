# %% [markdown]
# <a href="https://colab.research.google.com/github/zsroberts1/Southeast_FPV/blob/main/Southeast_PySAM_WeatherFiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nrel-PySAM
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 MB 14.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import csv
import pandas as pd
import PySAM.ResourceTools as tools
import PySAM.Pvwattsv8 as pv

# %%
# --- Initialize Solar Resource Fetcher with minimum parameters ---
nsrdbfetcher = tools.FetchResourceFiles(
                tech='solar',
                nrel_api_key='yeoz2Q0pxInQRefZKftZD8FyUDMHHcgUviHYZbem',  ## your NREL API key
                nrel_api_email='zacharysroberts1@gmail.com', ## the email used to obtain API key
                resource_dir='/content/drive/MyDrive/DATA/Weather_data', ## path to store weather files
                workers=1)


## get weather files in list to check for duplicats
kW_filename = open('/content/drive/MyDrive/DATA' ## path to folder containing location and unique ID for each location in study (e.g., waterbodies)
                   '/ClimateCrisis_Coords.csv', 'r') ## file name
file = csv.DictReader(kW_filename)
weather_files = []

for col in file:
    weather_files.append(col['weather_files'])
lst = []

for index, item in enumerate(weather_files):

    path = ("/content/drive/MyDrive/DATA" ## path to store new weather files
            "/Weather_data/%s") % weather_files[index] ## folder for new weather files
    isExist = os.path.exists(path)
    if not isExist:
        print(f"Downloading Weather File: {path}")
        df = pd.read_csv(
            "/content/drive/MyDrive/DATA" ## path to folder containing location and unique ID for each location in study (e.g., waterbodies)
            "/ClimateCrisis_Coords.csv") ## filename

        x = (df.iloc[index]['Lon'])
        y = (df.iloc[index]['Lat'])
        lst_tuple = (x, y)
        lst.append(lst_tuple)


## list of (lon, lat) tuples or shepely points
#lon_lats = lst_tuple
lon_lats = lst
nsrdbfetcher.fetch(lon_lats)

## Get resource data file path
nsrdb_path_dict = nsrdbfetcher.resource_file_paths_dict
nsrdb_fp = nsrdb_path_dict[lon_lats[0]]
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
#
# Starting data download for solar using 1 thread workers.
# Getting list of available NSRDB files for 36.291, -77.386.
# List of available data saved to /content/drive/MyDrive/DATA/Weather_data/nsrdb_data_query_response_36.291_-77.386.json.
# https://developer.nrel.gov/api/nsrdb/v2/solar/psm3-tmy-download.csv?names=tmy&wkt=POINT%28-77.386+36.291%29&interval=60&api_key=yeoz2Q0pxInQRefZKftZD8FyUDMHHcgUviHYZbem&email=zacharysroberts1@gmail.com&utc=false
# ...
# Success! File downloaded to /content/drive/MyDrive/DATA/Weather_data/nsrdb_36.291_-77.386_psm3-tmy_60_tmy.csv.
# Getting list of available NSRDB files for 35.575, -75.387.
# List of available data saved to /content/drive/MyDrive/DATA/Weather_data/nsrdb_data_query_response_35.575_-75.387.json.
# ...
